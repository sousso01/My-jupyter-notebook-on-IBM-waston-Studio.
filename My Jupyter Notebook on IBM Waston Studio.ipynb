# %% [markdown]
# # My Jupyter Note Notebook on IBM Waston Studio

# %% [markdown]
# **Yves BAYARO**
#
# I'm student at Uinversity of Lomé

# %% [markdown]
# *I'm interested in data science because first of all I like to play with data. And later I wish to occupy a position as responsible for actuarial studies in a bank*

# %% [markdown]
# ### my code makes it possible to draw curves which connect points whose abscissas and ordinates are provided in tables.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 3, 4, 6])
y = np.array([2, 3, 5, 1])
plt.plot(x, y)

plt.show()

# %% [markdown]
# ![This is an image](https://myoctocat.com/assets/images/base-octocat.svg)
#
# - one
# - two
# - three
# - four
# - five
#
# 1. James Madison
# 2. James Monroe
# 3. John Quincy Adams
